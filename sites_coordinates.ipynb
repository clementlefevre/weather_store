# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df_sites = pd.read_csv("all_sites.csv",sep=",")


df_sites['customer']=df_sites["customer_name"].str.extract("//(.+?):")
df_sites.columns
df_sites= df_sites[df_sites.deactivated==0]
df_sites = df_sites[[ u'idbldsite', u'sname', u'timezone', u'latitude', u'longitude',
      u'customer']]
df_sites=df_sites[~df_sites.latitude.isnull()]
df_sites['coordinates']=df_sites.apply(lambda x : str(x.latitude)+";"+str(x.longitude),axis=1)
groupy = df_sites.groupby('coordinates').count()
selected_customers = df_sites.customer.value_counts()
      
selected_customers = ['dwe-thalia','dwe-jackwolfskin','dwe-closed','dwe-globetrotter','dwe_visilab_2014',
 'dwe_arcadia_2015',
 'dwe_closed_2013',
 'dwe_libertywoman_2016',
 'dwe_1aoutlet_2014',

 'dwe_samsonite_2015',
 'dwe_oberpaur_2013',
 'dwe_clinton_2013',
 'dwe_knauber_2016',
 'dwe_mensing_2016']

df_sites_weather = df_sites[df_sites.customer.isin(selected_customers)]
# Out:
# /home/ramon/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
db_params =  'postgresql://dwe-froggy:dwe-froggy@localhost:5432/DWE_FROGGY_2016'
engine = create_engine(db_params,encoding = 'utf-8')

# %%
df_weather = pd.read_sql_query("select * from weather_data",
                                 con=engine)

# %%
df_weather[df_weather.site_id==1151][df_weather.period=='hour']
# Out:
# /home/ramon/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           id period    data_type             updated            dateTime  tt  \
# 0        411   hour  observation 2016-11-17 19:00:00 2016-11-16 01:00:00   6
# 2        413   hour  observation 2016-11-17 19:00:00 2016-11-16 02:00:00   7
# 3        414   hour  observation 2016-11-17 19:00:00 2016-11-16 03:00:00   7
# 4        415   hour  observation 2016-11-17 19:00:00 2016-11-16 04:00:00   7
# 5        416   hour  observation 2016-11-17 19:00:00 2016-11-16 05:00:00   7
# 6        417   hour  observation 2016-11-17 19:00:00 2016-11-16 06:00:00   7
# 7        418   hour  observation 2016-11-17 19:00:00 2016-11-16 07:00:00   6
# 8        419   hour  observation 2016-11-17 19:00:00 2016-11-16 08:00:00   7
# 9        420   hour  observation 2016-11-17 19:00:00 2016-11-16 09:00:00   6
# 10       421   hour  observation 2016-11-17 19:00:00 2016-11-16 10:00:00   7
# 11       422   hour  observation 2016-11-17 19:00:00 2016-11-16 11:00:00   7
# 12       423   hour  observation 2016-11-17 19:00:00 2016-11-16 12:00:00   8
# 13       424   hour  observation 2016-11-17 19:00:00 2016-11-16 13:00:00   8
# 14       425   hour  observation 2016-11-17 19:00:00 2016-11-16 14:00:00   8
# 15       426   hour  observation 2016-11-17 19:00:00 2016-11-16 15:00:00   8
# 16       427   hour  observation 2016-11-17 19:00:00 2016-11-16 16:00:00   8
